# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()
for i in range(2):
    filename = f"python_100_10000_{i+1}.csv"
    df_sub = pd.read_csv(filename)
    df = pd.concat([df, df_sub], ignore_index=True)
    
df = df.drop(columns=['Unnamed: 0'])
# Out:
#                                 name  \
# 0      zalandoresearch/fashion-mnist
# 1     Embedding/Chinese-Word-Vectors
# 2               MorvanZhou/tutorials
# 3            PySimpleGUI/PySimpleGUI
# 4                          dask/dask
# ..                               ...
# 195                Yorko/mlcourse.ai
# 196                rougier/numpy-100
# 197               deepmind/alphafold
# 198  30-seconds/30-seconds-of-python
# 199               ReFirmLabs/binwalk
#
#                                                    url  star_count  \
# 0     https://github.com/zalandoresearch/fashion-mnist        9967
# 1    https://github.com/Embedding/Chinese-Word-Vectors        9946
# 2              https://github.com/MorvanZhou/tutorials        9910
# 3           https://github.com/PySimpleGUI/PySimpleGUI        9863
# 4                         https://github.com/dask/dask        9807
# ..                                                 ...         ...
# 195               https://github.com/Yorko/mlcourse.ai        8188
# 196               https://github.com/rougier/numpy-100        8179
# 197              https://github.com/deepmind/alphafold        8194
# 198  https://github.com/30-seconds/30-seconds-of-py...        8181
# 199              https://github.com/ReFirmLabs/binwalk        8178
#
#                                             license  contributor_count  \
# 0                                       MIT License                 16
# 1                                Apache License 2.0                  3
# 2                                       MIT License                  9
# 3            GNU Lesser General Public License v3.0                 18
# 4           BSD 3-Clause "New" or "Revised" License                528
# ..                                              ...                ...
# 195                                           Other                  3
# 196                                     MIT License                 48
# 197                              Apache License 2.0                 12
# 198  Creative Commons Attribution 4.0 International                 77
# 199                                     MIT License                 80
#
#        size  watchers_count  forks  github_pages  open_issues  topics_count  \
# 0    108395            9967   2586         False           24            11
# 1      1477            9946   2176         False           42             6
# 2     62652            9910   5608         False           13             9
# 3    218325            9863   1489          True          654            20
# 4     52943            9807   1476         False          730             8
# ..      ...             ...    ...           ...          ...           ...
# 195  398527            8188   5421          True            3            17
# 196     499            8179   4328         False           39             5
# 197    5953            8194   1349         False           91             0
# 198   68456            8181   1238         False            2             8
# 199   45199            8178   1262         False          144             0
#
#                created_at            updated_at  allow_forking  \
# 0    2017-08-25T12:05:15Z  2022-04-27T18:39:55Z           True
# 1    2018-01-09T09:48:49Z  2022-04-28T08:57:29Z           True
# 2    2016-05-29T13:29:44Z  2022-04-28T07:44:40Z           True
# 3    2018-07-11T18:28:58Z  2022-04-28T09:02:07Z           True
# 4    2015-01-04T18:50:00Z  2022-04-28T03:04:06Z           True
# ..                    ...                   ...            ...
# 195  2017-02-27T08:32:20Z  2022-04-28T02:49:33Z           True
# 196  2014-05-27T04:09:47Z  2022-04-28T07:59:56Z           True
# 197  2021-06-17T14:06:06Z  2022-04-28T09:25:00Z           True
# 198  2018-01-08T12:17:16Z  2022-04-28T06:01:33Z           True
# 199  2013-11-15T20:45:40Z  2022-04-27T21:22:26Z           True
#
#      total_issue_count  commit_count licence
# 0                   98           224     NaN
# 1                  147           133     NaN
# 2                   66           541     NaN
# 3                 2731          5974     NaN
# 4                 4226          7139     NaN
# ..                 ...           ...     ...
# 195                 95            40     NaN
# 196                 63           273     NaN
# 197                401            51     NaN
# 198                 77          1645     NaN
# 199                381          1233     NaN
#
# [200 rows x 17 columns]

# %%
df.head()
# Out:
#                              name  \
# 0   zalandoresearch/fashion-mnist
# 1  Embedding/Chinese-Word-Vectors
# 2            MorvanZhou/tutorials
# 3         PySimpleGUI/PySimpleGUI
# 4                       dask/dask
#
#                                                  url  star_count  \
# 0   https://github.com/zalandoresearch/fashion-mnist        9967
# 1  https://github.com/Embedding/Chinese-Word-Vectors        9946
# 2            https://github.com/MorvanZhou/tutorials        9910
# 3         https://github.com/PySimpleGUI/PySimpleGUI        9863
# 4                       https://github.com/dask/dask        9807
#
#                                    license  contributor_count    size  \
# 0                              MIT License                 16  108395
# 1                       Apache License 2.0                  3    1477
# 2                              MIT License                  9   62652
# 3   GNU Lesser General Public License v3.0                 18  218325
# 4  BSD 3-Clause "New" or "Revised" License                528   52943
#
#    watchers_count  forks  github_pages  open_issues  topics_count  \
# 0            9967   2586         False           24            11
# 1            9946   2176         False           42             6
# 2            9910   5608         False           13             9
# 3            9863   1489          True          654            20
# 4            9807   1476         False          730             8
#
#              created_at            updated_at  allow_forking  \
# 0  2017-08-25T12:05:15Z  2022-04-27T18:39:55Z           True
# 1  2018-01-09T09:48:49Z  2022-04-28T08:57:29Z           True
# 2  2016-05-29T13:29:44Z  2022-04-28T07:44:40Z           True
# 3  2018-07-11T18:28:58Z  2022-04-28T09:02:07Z           True
# 4  2015-01-04T18:50:00Z  2022-04-28T03:04:06Z           True
#
#    total_issue_count  commit_count licence
# 0                 98           224     NaN
# 1                147           133     NaN
# 2                 66           541     NaN
# 3               2731          5974     NaN
# 4               4226          7139     NaN

# %%
df.isnull().sum()
# Out:
# name                   0
# url                    0
# star_count             0
# license               12
# contributor_count      0
# size                   0
# watchers_count         0
# forks                  0
# github_pages           0
# open_issues            0
# topics_count           0
# created_at             0
# updated_at             0
# allow_forking          0
# total_issue_count      0
# commit_count           0
# licence              188
# dtype: int64

# %% [markdown]
# **We need to fill the null values by looking them on Github by hand.

# %%
df.describe()
# Out:
#         star_count  contributor_count          size  watchers_count  \
# count   200.000000         200.000000  2.000000e+02      200.000000
# mean   8926.045000         150.070000  5.125548e+04     8926.045000
# std     516.611741         208.133908  1.197021e+05      516.611741
# min    8178.000000           3.000000  3.360000e+02     8178.000000
# 25%    8478.750000          21.750000  4.201250e+03     8478.750000
# 50%    8834.500000          75.500000  1.850550e+04     8834.500000
# 75%    9369.750000         200.500000  5.246775e+04     9369.750000
# max    9967.000000        1264.000000  1.046070e+06     9967.000000
#
#              forks  open_issues  topics_count  total_issue_count  commit_count
# count   200.000000   200.000000    200.000000         200.000000    200.000000
# mean   1807.600000   243.120000      7.340000        1002.200000   3427.870000
# std    1029.030934   509.348589      5.802824        1723.384102   7012.528908
# min     337.000000     1.000000      0.000000           0.000000     15.000000
# 25%    1079.250000    32.000000      3.000000          70.000000    317.500000
# 50%    1570.500000   118.500000      6.000000         381.000000   1125.500000
# 75%    2312.000000   242.500000     10.000000        1115.000000   2841.000000
# max    5608.000000  4452.000000     20.000000       11765.000000  50787.000000
