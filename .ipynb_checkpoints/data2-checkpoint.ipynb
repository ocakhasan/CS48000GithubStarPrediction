# %% [markdown]
# # Reading Data

# %%
import pandas as pd
import numpy as np
import os

# %%
"""def create_dataframe():
    df = pd.DataFrame()
    cwd = os.getcwd()
    data_folder = os.path.join(cwd, "data")
    for i in range(41):
        filename = f"python_100_10000_{i}.csv"
        filename = os.path.join(data_folder, filename)
        df_sub = pd.read_csv(filename)
        df = pd.concat([df, df_sub], ignore_index=True)

    df = df.drop(columns=['Unnamed: 0'])
    return df
    
"""

files_added = ["_100_1000_1.csv", "_100_1000_2.csv", "_100_1000_3.csv", "_100_1000_4.csv", "_100_1000_5.csv",
              "_6000_7000_0.csv"]

def create_dataframe():
    df = pd.read_csv("total_scraped_data.csv")
    df = df.drop(columns=['Unnamed: 0'])
    return df

# %%
df = create_dataframe()
df.head()
# Out:
#    allow_forking  commit_count  contributor_count            created_at  \
# 0            1.0          5524              312.0  2020-05-19T02:37:13Z
# 1            1.0           224               16.0  2017-08-25T12:05:15Z
# 2            1.0           133                3.0  2018-01-09T09:48:49Z
# 3            1.0          6023               18.0  2018-07-11T18:28:58Z
# 4            1.0           541                9.0  2016-05-29T13:29:44Z
#
#     forks  github_pages                                 license  \
# 0   882.0           0.0                             MIT License
# 1  2590.0           0.0                             MIT License
# 2  2181.0           0.0                      Apache License 2.0
# 3  1494.0           1.0  GNU Lesser General Public License v3.0
# 4  5612.0           0.0                             MIT License
#
#                              name  open_issues      size  star_count  \
# 0            ManimCommunity/manim        351.0   33506.0      9951.0
# 1   zalandoresearch/fashion-mnist         24.0  108395.0      9998.0
# 2  Embedding/Chinese-Word-Vectors         42.0    1477.0      9976.0
# 3         PySimpleGUI/PySimpleGUI        659.0  261676.0      9924.0
# 4            MorvanZhou/tutorials         13.0   62652.0      9944.0
#
#    topics_count  total_issue_count            updated_at  \
# 0           4.0             1030.0  2022-05-09T17:53:54Z
# 1          11.0               98.0  2022-05-09T09:30:18Z
# 2           6.0              147.0  2022-05-09T14:13:08Z
# 3          20.0             2750.0  2022-05-09T15:50:27Z
# 4           9.0               66.0  2022-05-09T11:56:21Z
#
#                                                  url  watchers_count
# 0            https://github.com/ManimCommunity/manim          9951.0
# 1   https://github.com/zalandoresearch/fashion-mnist          9998.0
# 2  https://github.com/Embedding/Chinese-Word-Vectors          9976.0
# 3         https://github.com/PySimpleGUI/PySimpleGUI          9924.0
# 4            https://github.com/MorvanZhou/tutorials          9944.0

# %%
df.dtypes
# Out:
# allow_forking        float64
# commit_count           int64
# contributor_count    float64
# created_at            object
# forks                float64
# github_pages         float64
# license               object
# name                  object
# open_issues          float64
# size                 float64
# star_count           float64
# topics_count         float64
# total_issue_count    float64
# updated_at            object
# url                   object
# watchers_count       float64
# dtype: object

# %% [markdown]
# ## Filling Null Values

# %%
df.isnull().sum()
# Out:
# allow_forking        0
# commit_count         0
# contributor_count    0
# created_at           0
# forks                0
# github_pages         0
# license              0
# name                 0
# open_issues          0
# size                 0
# star_count           0
# topics_count         0
# total_issue_count    0
# updated_at           0
# url                  0
# watchers_count       0
# dtype: int64

# %%
def convert_str_to_int(i):
    thousands = i.split(",")
    if len(thousands) == 1:
        return int(thousands[0])
    return int(thousands[0]) * 1000 + int(thousands[1])

# %%
convert_str_to_int("3")
# Out:
# 3

# %%
df[df["total_issue_count"] == 0].shape
# Out:
# (15, 16)

# %%
"""
from urllib.request import urlopen

from bs4 import BeautifulSoup

for i in df[df["total_issue_count"] == 0].index:
    
    url = df.loc[i, "url"] + "/issues"
    
    if url == "https://github.com/notAI-tech/NudeNet/issues":
        continue

    page = urlopen(url)

    html = page.read().decode("utf-8")

    soup = BeautifulSoup(html, "html.parser")
    
    open_issue = ""
    closed_issue = ""
    buttons = soup.find_all("a", {"class": "btn-link"})

    
    for idx, j in enumerate(buttons[:2]):
        if idx == 0:
            open_issue = j.text.strip().split(" ")[0]
        else:
            closed_issue = j.text.strip().split(" ")[0]
            
    
            
    
    
    try:
        total_issue = convert_str_to_int(open_issue) + convert_str_to_int(closed_issue)
        print(f"{url}: open issue: {open_issue}, closed issue:{closed_issue}, total issue: {total_issue}")
        df.loc[i, "total_issue_count"] = total_issue
    except Exception as e:
        continue
    
"""
# Out:
# https://github.com/instillai/deep-learning-roadmap/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/benedekrozemberczki/awesome-decision-tree-papers/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/INTERMT/Awesome-PyTorch-Chinese/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/FeeiCN/Security-PPT/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/viewflow/viewflow/issues: open issue: 23, closed issue:247, total issue: 270
# https://github.com/buckyroberts/Source-Code-from-Tutorials/issues: open issue: 34, closed issue:8, total issue: 42
# https://github.com/mozilla/MozDef/issues: open issue: 0, closed issue:391, total issue: 391
# https://github.com/igul222/improved_wgan_training/issues: open issue: 39, closed issue:49, total issue: 88
# https://github.com/wuub/SublimeREPL/issues: open issue: 249, closed issue:202, total issue: 451
# https://github.com/emirozer/fake2db/issues: open issue: 7, closed issue:15, total issue: 22
# https://github.com/maxpumperla/hyperas/issues: open issue: 93, closed issue:158, total issue: 251
# https://github.com/IntelLabs/coach/issues: open issue: 80, closed issue:183, total issue: 263
# https://github.com/thu-ml/zhusuan/issues: open issue: 7, closed issue:53, total issue: 60
# https://github.com/taojy123/KeymouseGo/issues: open issue: 4, closed issue:86, total issue: 90
# https://github.com/ZQPei/deep_sort_pytorch/issues: open issue: 108, closed issue:112, total issue: 220
# https://github.com/titoBouzout/SideBarEnhancements/issues: open issue: 3, closed issue:377, total issue: 380
# https://github.com/josiahcarlson/redis-in-action/issues: open issue: 2, closed issue:33, total issue: 35
# https://github.com/jupyterhub/binderhub/issues: open issue: 175, closed issue:446, total issue: 621
# https://github.com/KupynOrest/DeblurGAN/issues: open issue: 131, closed issue:76, total issue: 207
# https://github.com/cbfinn/maml/issues: open issue: 40, closed issue:36, total issue: 76
# https://github.com/oilshell/oil/issues: open issue: 375, closed issue:544, total issue: 919
# https://github.com/cleardusk/3DDFA_V2/issues: open issue: 71, closed issue:54, total issue: 125
# https://github.com/minimaxir/facebook-page-post-scraper/issues: open issue: 53, closed issue:37, total issue: 90
# https://github.com/sunscrapers/djoser/issues: open issue: 124, closed issue:282, total issue: 406
# https://github.com/ahupp/python-magic/issues: open issue: 27, closed issue:146, total issue: 173
# https://github.com/pantsbuild/pex/issues: open issue: 138, closed issue:710, total issue: 848
# https://github.com/mhallsmoore/qstrader/issues: open issue: 96, closed issue:127, total issue: 223
# https://github.com/python-security/pyt/issues: open issue: 21, closed issue:77, total issue: 98
# https://github.com/kaonashi-tyc/zi2zi/issues: open issue: 51, closed issue:36, total issue: 87
# https://github.com/paarthneekhara/text-to-image/issues: open issue: 44, closed issue:18, total issue: 62
# https://github.com/ctfs/write-ups-2017/issues: open issue: 3,053, closed issue:840, total issue: 3893
# https://github.com/megvii-research/ICCV2019-LearningToPaint/issues: open issue: 0, closed issue:46, total issue: 46
# https://github.com/lxml/lxml/issues: open issue: 7, closed issue:278, total issue: 285
# https://github.com/anopara/genetic-drawing/issues: open issue: 7, closed issue:2, total issue: 9
# https://github.com/k4m4/kickthemout/issues: open issue: 94, closed issue:263, total issue: 357
# https://github.com/Zhongdao/Towards-Realtime-MOT/issues: open issue: 119, closed issue:116, total issue: 235
# https://github.com/justquick/django-activity-stream/issues: open issue: 15, closed issue:279, total issue: 294
# https://github.com/dortania/OpenCore-Legacy-Patcher/issues: open issue: 13, closed issue:875, total issue: 888
# https://github.com/pytest-dev/pytest-testinfra/issues: open issue: 106, closed issue:201, total issue: 307
# https://github.com/PetrochukM/PyTorch-NLP/issues: open issue: 18, closed issue:49, total issue: 67
# https://github.com/pyston/pyston/issues: open issue: 18, closed issue:42, total issue: 60
# https://github.com/asappresearch/sru/issues: open issue: 57, closed issue:67, total issue: 124
# https://github.com/miguelgrinberg/Flask-Migrate/issues: open issue: 10, closed issue:363, total issue: 373
# https://github.com/PyMySQL/mysqlclient/issues: open issue: 12, closed issue:270, total issue: 282
# https://github.com/Shougo/denite.nvim/issues: open issue: 1, closed issue:540, total issue: 541
# https://github.com/minimaxir/person-blocker/issues: open issue: 8, closed issue:0, total issue: 8
# https://github.com/EntilZha/PyFunctional/issues: open issue: 7, closed issue:120, total issue: 127
# https://github.com/princeton-nlp/SimCSE/issues: open issue: 9, closed issue:151, total issue: 160
# https://github.com/xingyizhou/CenterTrack/issues: open issue: 159, closed issue:94, total issue: 253
# https://github.com/Roujack/mathAI/issues: open issue: 11, closed issue:12, total issue: 23
# https://github.com/kizniche/Mycodo/issues: open issue: 37, closed issue:1,033, total issue: 1070
# https://github.com/ShawnBIT/UNet-family/issues: open issue: 4, closed issue:1, total issue: 5
# https://github.com/google-research/electra/issues: open issue: 48, closed issue:69, total issue: 117
# https://github.com/iambus/xunlei-lixian/issues: open issue: 171, closed issue:241, total issue: 412
# https://github.com/Netflix-Skunkworks/stethoscope/issues: open issue: 14, closed issue:23, total issue: 37
# https://github.com/wkentaro/gdown/issues: open issue: 17, closed issue:81, total issue: 98
# https://github.com/crossbario/crossbar/issues: open issue: 250, closed issue:925, total issue: 1175
# https://github.com/python-excel/xlrd/issues: open issue: 0, closed issue:159, total issue: 159
# https://github.com/hunglc007/tensorflow-yolov4-tflite/issues: open issue: 270, closed issue:122, total issue: 392
# https://github.com/etsy/logster/issues: open issue: 5, closed issue:31, total issue: 36
# https://github.com/oliver006/elasticsearch-gmail/issues: open issue: 1, closed issue:9, total issue: 10
# https://github.com/open-mmlab/mmselfsup/issues: open issue: 9, closed issue:123, total issue: 132
# https://github.com/zvtvz/zvt/issues: open issue: 12, closed issue:91, total issue: 103
# https://github.com/sml2h3/ddddocr/issues: open issue: 11, closed issue:46, total issue: 57
# https://github.com/TailorDev/Watson/issues: open issue: 87, closed issue:148, total issue: 235
# https://github.com/quay/quay/issues: open issue: 16, closed issue:1,272, total issue: 1288
# https://github.com/benedekrozemberczki/awesome-decision-tree-papers/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/mdn/kuma/issues: open issue: 158, closed issue:1,085, total issue: 1243
# https://github.com/Tencent/ObjectDetection-OneStageDet/issues: open issue: 49, closed issue:53, total issue: 102
# https://github.com/BlankerL/DXY-COVID-19-Crawler/issues: open issue: 6, closed issue:118, total issue: 124
# https://github.com/mongodb/motor/issues: open issue: 0, closed issue:166, total issue: 166
# https://github.com/giswqs/geemap/issues: open issue: 12, closed issue:349, total issue: 361
# https://github.com/scikit-learn-contrib/category_encoders/issues: open issue: 68, closed issue:175, total issue: 243
# https://github.com/samuraisam/pyapns/issues: open issue: 22, closed issue:38, total issue: 60
# https://github.com/saffsd/langid.py/issues: open issue: 26, closed issue:45, total issue: 71
# https://github.com/Kaggle/docker-python/issues: open issue: 18, closed issue:271, total issue: 289
# https://github.com/rthalley/dnspython/issues: open issue: 0, closed issue:407, total issue: 407
# https://github.com/ChenglongChen/tensorflow-DeepFM/issues: open issue: 46, closed issue:34, total issue: 80
# https://github.com/keras-team/keras-applications/issues: open issue: 60, closed issue:103, total issue: 163
# https://github.com/SublimeLinter/SublimeLinter/issues: open issue: 20, closed issue:1,225, total issue: 1245
# https://github.com/exchangeratesapi/exchangeratesapi/issues: open issue: 45, closed issue:47, total issue: 92
# https://github.com/iBaa/PlexConnect/issues: open issue: 25, closed issue:402, total issue: 427
# https://github.com/owocki/pytrader/issues: open issue: 90, closed issue:36, total issue: 126
# https://github.com/chartbeat-labs/textacy/issues: open issue: 29, closed issue:222, total issue: 251
# https://github.com/truenas/middleware/issues: open issue: 3, closed issue:8, total issue: 11
# https://github.com/google/skywater-pdk/issues: open issue: 142, closed issue:81, total issue: 223
# https://github.com/ross/requests-futures/issues: open issue: 17, closed issue:61, total issue: 78
# https://github.com/stav121/i3wm-themer/issues: open issue: 18, closed issue:64, total issue: 82
# https://github.com/kliment/Printrun/issues: open issue: 155, closed issue:682, total issue: 837
# https://github.com/johnwheeler/flask-ask/issues: open issue: 25, closed issue:89, total issue: 114
# https://github.com/codingo/Reconnoitre/issues: open issue: 9, closed issue:44, total issue: 53
# https://github.com/NCSC-NL/log4shell/issues: open issue: 0, closed issue:98, total issue: 98
# https://github.com/abhinavsingh/proxy.py/issues: open issue: 39, closed issue:219, total issue: 258
# https://github.com/tiny-pilot/tinypilot/issues: open issue: 77, closed issue:257, total issue: 334
# https://github.com/ermaozi/get_subscribe/issues: open issue: 4, closed issue:21, total issue: 25
# https://github.com/freemocap/freemocap/issues: open issue: 28, closed issue:31, total issue: 59
# https://github.com/TeamUltroid/Ultroid/issues: open issue: 1, closed issue:23, total issue: 24
# https://github.com/zhanyong-wan/dongbei/issues: open issue: 30, closed issue:60, total issue: 90
# https://github.com/cujanovic/SSRF-Testing/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/quantmind/pulsar/issues: open issue: 28, closed issue:224, total issue: 252
# https://github.com/ActiveState/code/issues: open issue: 19, closed issue:7, total issue: 26
# https://github.com/amscanne/huptime/issues: open issue: 3, closed issue:10, total issue: 13
# https://github.com/moskomule/senet.pytorch/issues: open issue: 0, closed issue:11, total issue: 11
# https://github.com/mikedh/trimesh/issues: open issue: 230, closed issue:870, total issue: 1100
# https://github.com/princeton-vl/RAFT/issues: open issue: 36, closed issue:92, total issue: 128
# https://github.com/raiden-network/raiden/issues: open issue: 298, closed issue:2,358, total issue: 2656
# https://github.com/mingyuliutw/UNIT/issues: open issue: 1, closed issue:107, total issue: 108
# https://github.com/abseil/abseil-py/issues: open issue: 13, closed issue:73, total issue: 86
# https://github.com/johnwheeler/flask-ask/issues: open issue: 25, closed issue:89, total issue: 114
# https://github.com/polakowo/vectorbt/issues: open issue: 98, closed issue:157, total issue: 255
# https://github.com/codingo/Reconnoitre/issues: open issue: 9, closed issue:44, total issue: 53
# https://github.com/NCSC-NL/log4shell/issues: open issue: 0, closed issue:98, total issue: 98
# https://github.com/abhinavsingh/proxy.py/issues: open issue: 39, closed issue:219, total issue: 258
# https://github.com/tiny-pilot/tinypilot/issues: open issue: 77, closed issue:257, total issue: 334
# https://github.com/ermaozi/get_subscribe/issues: open issue: 4, closed issue:21, total issue: 25
# https://github.com/freemocap/freemocap/issues: open issue: 28, closed issue:31, total issue: 59
# https://github.com/TeamUltroid/Ultroid/issues: open issue: 1, closed issue:23, total issue: 24
# https://github.com/zhanyong-wan/dongbei/issues: open issue: 30, closed issue:60, total issue: 90
# https://github.com/cujanovic/SSRF-Testing/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/quantmind/pulsar/issues: open issue: 28, closed issue:224, total issue: 252
# https://github.com/ActiveState/code/issues: open issue: 19, closed issue:7, total issue: 26
# https://github.com/amscanne/huptime/issues: open issue: 3, closed issue:10, total issue: 13
# https://github.com/moskomule/senet.pytorch/issues: open issue: 0, closed issue:11, total issue: 11
# https://github.com/mikedh/trimesh/issues: open issue: 230, closed issue:870, total issue: 1100
# https://github.com/princeton-vl/RAFT/issues: open issue: 36, closed issue:92, total issue: 128
# https://github.com/raiden-network/raiden/issues: open issue: 298, closed issue:2,358, total issue: 2656
# https://github.com/mingyuliutw/UNIT/issues: open issue: 1, closed issue:107, total issue: 108
# https://github.com/abseil/abseil-py/issues: open issue: 13, closed issue:73, total issue: 86
# https://github.com/Tinche/aiofiles/issues: open issue: 44, closed issue:46, total issue: 90
# https://github.com/shuup/shuup/issues: open issue: 141, closed issue:290, total issue: 431
# https://github.com/FeeiCN/GSIL/issues: open issue: 2, closed issue:60, total issue: 62
# https://github.com/chuanqi305/MobileNet-SSD/issues: open issue: 148, closed issue:44, total issue: 192
# https://github.com/boston-dynamics/spot-sdk/issues: open issue: 27, closed issue:25, total issue: 52
# https://github.com/mara/mara-pipelines/issues: open issue: 7, closed issue:14, total issue: 21
# https://github.com/rail-berkeley/rlkit/issues: open issue: 28, closed issue:93, total issue: 121
# https://github.com/xavierd/clang_complete/issues: open issue: 165, closed issue:223, total issue: 388
# https://github.com/alfiopuglisi/guietta/issues: open issue: 8, closed issue:23, total issue: 31
# https://github.com/xhtml2pdf/xhtml2pdf/issues: open issue: 123, closed issue:207, total issue: 330
# https://github.com/mljar/mljar-supervised/issues: open issue: 84, closed issue:392, total issue: 476
# https://github.com/SeanNaren/deepspeech.pytorch/issues: open issue: 4, closed issue:482, total issue: 486
# https://github.com/johnwheeler/flask-ask/issues: open issue: 25, closed issue:89, total issue: 114
# https://github.com/rsennrich/subword-nmt/issues: open issue: 4, closed issue:77, total issue: 81
# https://github.com/open-mmlab/mmpose/issues: open issue: 57, closed issue:511, total issue: 568
# https://github.com/danieldjohnson/biaxial-rnn-music-composition/issues: open issue: 7, closed issue:21, total issue: 28
# https://github.com/aws-cloudformation/cfn-lint/issues: open issue: 104, closed issue:696, total issue: 800
# https://github.com/moskomule/senet.pytorch/issues: open issue: 0, closed issue:11, total issue: 11
# https://github.com/jiupinjia/SkyAR/issues: open issue: 5, closed issue:14, total issue: 19
# https://github.com/sc0tfree/updog/issues: open issue: 28, closed issue:10, total issue: 38
# https://github.com/elaine-zheng/summer2020internships/issues: open issue: 3, closed issue:8, total issue: 11
# https://github.com/facebookresearch/video-nonlocal-net/issues: open issue: 37, closed issue:38, total issue: 75
# https://github.com/wemake-services/wemake-python-styleguide/issues: open issue: 82, closed issue:924, total issue: 1006
# https://github.com/CamDavidsonPilon/lifelines/issues: open issue: 218, closed issue:638, total issue: 856
# https://github.com/yanshengjia/ml-road/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/yaronzz/Tidal-Media-Downloader/issues: open issue: 314, closed issue:453, total issue: 767
# https://github.com/crista/exercises-in-programming-style/issues: open issue: 3, closed issue:10, total issue: 13
# https://github.com/zjhuang22/maskscoring_rcnn/issues: open issue: 60, closed issue:47, total issue: 107
# https://github.com/tarunkant/Gopherus/issues: open issue: 2, closed issue:8, total issue: 10
# https://github.com/josh-richardson/cadmus/issues: open issue: 40, closed issue:31, total issue: 71
# https://github.com/mitogen-hq/mitogen/issues: open issue: 186, closed issue:238, total issue: 424
# https://github.com/salesforce/awd-lstm-lm/issues: open issue: 55, closed issue:46, total issue: 101
# https://github.com/milesmcc/shynet/issues: open issue: 28, closed issue:105, total issue: 133
# https://github.com/boston-dynamics/spot-sdk/issues: open issue: 27, closed issue:25, total issue: 52
# https://github.com/mozilla/cipherscan/issues: open issue: 28, closed issue:46, total issue: 74
# https://github.com/biubug6/Pytorch_Retinaface/issues: open issue: 125, closed issue:56, total issue: 181
# https://github.com/ywangd/stash/issues: open issue: 86, closed issue:199, total issue: 285
# https://github.com/RoliSoft/WSL-Distribution-Switcher/issues: open issue: 50, closed issue:43, total issue: 93
# https://github.com/mvantellingen/python-zeep/issues: open issue: 322, closed issue:649, total issue: 971
# https://github.com/sxyu/svox2/issues: open issue: 48, closed issue:25, total issue: 73
# https://github.com/warpling/Macmoji/issues: open issue: 5, closed issue:24, total issue: 29
# https://github.com/llSourcell/YOLO_Object_Detection/issues: open issue: 24, closed issue:7, total issue: 31
# https://github.com/pypa/setuptools/issues: open issue: 486, closed issue:1,564, total issue: 2050
# https://github.com/youyuge34/PI-REC/issues: open issue: 1, closed issue:13, total issue: 14
# https://github.com/tryolabs/requestium/issues: open issue: 4, closed issue:18, total issue: 22
# https://github.com/mcordts/cityscapesScripts/issues: open issue: 40, closed issue:80, total issue: 120
# https://github.com/datamllab/rlcard/issues: open issue: 43, closed issue:114, total issue: 157
# https://github.com/pytorch/audio/issues: open issue: 130, closed issue:464, total issue: 594
# https://github.com/deviantfero/wpgtk/issues: open issue: 10, closed issue:179, total issue: 189
# https://github.com/xianhu/PSpider/issues: open issue: 0, closed issue:28, total issue: 28
# https://github.com/iswbm/pycharm-guide/issues: open issue: 10, closed issue:1, total issue: 11
# https://github.com/apenwarr/redo/issues: open issue: 10, closed issue:34, total issue: 44
# https://github.com/kaxap/arl/issues: open issue: 1, closed issue:10, total issue: 11
# https://github.com/PyCQA/prospector/issues: open issue: 35, closed issue:276, total issue: 311
# https://github.com/Maratyszcza/PeachPy/issues: open issue: 21, closed issue:61, total issue: 82
# https://github.com/fossasia/query-server/issues: open issue: 23, closed issue:199, total issue: 222
# https://github.com/rentruewang/koila/issues: open issue: 9, closed issue:15, total issue: 24
# https://github.com/mikepound/mazesolving/issues: open issue: 5, closed issue:8, total issue: 13
# https://github.com/openstenoproject/plover/issues: open issue: 159, closed issue:485, total issue: 644
# https://github.com/AlexxIT/SonoffLAN/issues: open issue: 22, closed issue:674, total issue: 696
# https://github.com/WongKinYiu/PyTorch_YOLOv4/issues: open issue: 282, closed issue:115, total issue: 397
# https://github.com/salesforce/ctrl/issues: open issue: 24, closed issue:53, total issue: 77
# https://github.com/google/pyringe/issues: open issue: 15, closed issue:9, total issue: 24
# https://github.com/gak/pycallgraph/issues: open issue: 48, closed issue:109, total issue: 157
# https://github.com/scrapy/dirbot/issues: open issue: 0, closed issue:24, total issue: 24
# https://github.com/Flagsmith/flagsmith/issues: open issue: 103, closed issue:337, total issue: 440
# https://github.com/cpfair/tapiriik/issues: open issue: 314, closed issue:118, total issue: 432
# https://github.com/engineer-man/youtube/issues: open issue: 0, closed issue:30, total issue: 30
# https://github.com/pyouroboros/ouroboros/issues: open issue: 7, closed issue:228, total issue: 235
# https://github.com/nobody132/masr/issues: open issue: 0, closed issue:4, total issue: 4
# https://github.com/ozan-oktay/Attention-Gated-Networks/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/fossasia/knitpat/issues: open issue: 1, closed issue:1, total issue: 2
# https://github.com/onejgordon/flow-dashboard/issues: open issue: 41, closed issue:83, total issue: 124
# https://github.com/HaujetZhao/QuickCut/issues: open issue: 23, closed issue:28, total issue: 51
# https://github.com/RhinoSecurityLabs/cloudgoat/issues: open issue: 14, closed issue:42, total issue: 56
# https://github.com/jstrieb/github-stats/issues: open issue: 13, closed issue:30, total issue: 43
# https://github.com/popey/sosumi-snap/issues: open issue: 25, closed issue:12, total issue: 37
# https://github.com/NVlabs/FUNIT/issues: open issue: 28, closed issue:18, total issue: 46
# https://github.com/ceph/ceph-ansible/issues: open issue: 6, closed issue:1,327, total issue: 1333
# https://github.com/fossasia/event-collect/issues: open issue: 0, closed issue:9, total issue: 9
# https://github.com/gothinkster/django-realworld-example-app/issues: open issue: 15, closed issue:10, total issue: 25
# https://github.com/pyscaffold/pyscaffold/issues: open issue: 16, closed issue:252, total issue: 268
# https://github.com/RosettaCommons/RoseTTAFold/issues: open issue: 62, closed issue:43, total issue: 105
# https://github.com/Roshanson/TextInfoExp/issues: open issue: 6, closed issue:7, total issue: 13
# https://github.com/fossasia/AYABInterface/issues: open issue: 12, closed issue:0, total issue: 12
# https://github.com/google/gin-config/issues: open issue: 28, closed issue:39, total issue: 67
# https://github.com/coleifer/sqlite-web/issues: open issue: 0, closed issue:82, total issue: 82
# https://github.com/calebstewart/pwncat/issues: open issue: 24, closed issue:128, total issue: 152
# https://github.com/CyberPunkMetalHead/Binance-News-Sentiment-Bot/issues: open issue: 9, closed issue:20, total issue: 29
# https://github.com/mbadry1/Top-Deep-Learning/issues: open issue: 2, closed issue:0, total issue: 2
# https://github.com/viper-framework/viper/issues: open issue: 56, closed issue:271, total issue: 327
# https://github.com/bearpaw/pytorch-classification/issues: open issue: 28, closed issue:16, total issue: 44
# https://github.com/googlecolab/colabtools/issues: open issue: 920, closed issue:1,767, total issue: 2687
# https://github.com/fossasia/x-mario-center/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/pyouroboros/ouroboros/issues: open issue: 7, closed issue:228, total issue: 235
# https://github.com/awslabs/aws-well-architected-labs/issues: open issue: 17, closed issue:75, total issue: 92
# https://github.com/cuthbertLab/music21/issues: open issue: 81, closed issue:484, total issue: 565
# https://github.com/nobody132/masr/issues: open issue: 0, closed issue:4, total issue: 4
# https://github.com/nlplab/brat/issues: open issue: 471, closed issue:866, total issue: 1337
# https://github.com/subbarayudu-j/TheAlgorithms-Python/issues: open issue: 3, closed issue:1, total issue: 4
# https://github.com/voxelmorph/voxelmorph/issues: open issue: 58, closed issue:274, total issue: 332
# https://github.com/huhamhire/huhamhire-hosts/issues: open issue: 54, closed issue:37, total issue: 91
# https://github.com/billzhong/inbox.py/issues: open issue: 1, closed issue:11, total issue: 12
# https://github.com/mhxion/awesome-discord-communities/issues: open issue: 10, closed issue:20, total issue: 30
# https://github.com/thewhiteh4t/pwnedOrNot/issues: open issue: 2, closed issue:45, total issue: 47
# https://github.com/lijiejie/BBScan/issues: open issue: 7, closed issue:33, total issue: 40
# https://github.com/ozan-oktay/Attention-Gated-Networks/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/fossasia/knitpat/issues: open issue: 1, closed issue:1, total issue: 2
# https://github.com/fossasia/event-collect/issues: open issue: 0, closed issue:9, total issue: 9
# https://github.com/abbeyokgo/PyOne/issues: open issue: 57, closed issue:73, total issue: 130
# https://github.com/JingyunLiang/SwinIR/issues: open issue: 15, closed issue:70, total issue: 85
# https://github.com/simplejson/simplejson/issues: open issue: 14, closed issue:170, total issue: 184
# https://github.com/Daniil-Osokin/lightweight-human-pose-estimation.pytorch/issues: open issue: 0, closed issue:247, total issue: 247
# https://github.com/requests/requests-oauthlib/issues: open issue: 84, closed issue:149, total issue: 233
# https://github.com/iam-abbas/Reddit-Stock-Trends/issues: open issue: 17, closed issue:14, total issue: 31
# https://github.com/openai/multiagent-particle-envs/issues: open issue: 46, closed issue:31, total issue: 77
# https://github.com/john-kurkowski/tldextract/issues: open issue: 19, closed issue:149, total issue: 168
# https://github.com/citronneur/rdpy/issues: open issue: 60, closed issue:38, total issue: 98
# https://github.com/fossasia/open-event-scripts/issues: open issue: 0, closed issue:2, total issue: 2
# https://github.com/RiweiChen/DeepFace/issues: open issue: 15, closed issue:22, total issue: 37
# https://github.com/mre/the-coding-interview/issues: open issue: 2, closed issue:6, total issue: 8
# https://github.com/riptideio/pymodbus/issues: open issue: 71, closed issue:384, total issue: 455
# https://github.com/chainer/chainercv/issues: open issue: 37, closed issue:168, total issue: 205
# https://github.com/blmoistawinde/HarvestText/issues: open issue: 11, closed issue:26, total issue: 37
# https://github.com/Koed00/django-q/issues: open issue: 233, closed issue:143, total issue: 376
# https://github.com/fossasia/x-mario-center/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/bhattsameer/Bombers/issues: open issue: 8, closed issue:46, total issue: 54
# https://github.com/facebookresearch/swav/issues: open issue: 27, closed issue:73, total issue: 100
# https://github.com/philipperemy/keras-tcn/issues: open issue: 6, closed issue:141, total issue: 147
# https://github.com/nickstenning/honcho/issues: open issue: 12, closed issue:89, total issue: 101
# https://github.com/lemonhu/stock-knowledge-graph/issues: open issue: 19, closed issue:2, total issue: 21
# https://github.com/QuantEcon/QuantEcon.py/issues: open issue: 59, closed issue:193, total issue: 252
# https://github.com/fossasia/open-event-legacy/issues: open issue: 6, closed issue:19, total issue: 25
# https://github.com/gramps-project/gramps/issues: open issue: 49, closed issue:1,323, total issue: 1372
# https://github.com/carpedm20/emoji/issues: open issue: 14, closed issue:102, total issue: 116
# https://github.com/jazzband/django-constance/issues: open issue: 27, closed issue:217, total issue: 244
# https://github.com/Gameye98/Lazymux/issues: open issue: 1, closed issue:75, total issue: 76
# https://github.com/AsuharietYgvar/AppleNeuralHash2ONNX/issues: open issue: 5, closed issue:3, total issue: 8
# https://github.com/brndnmtthws/thetagang/issues: open issue: 6, closed issue:14, total issue: 20
# https://github.com/weaveworks/grafanalib/issues: open issue: 32, closed issue:97, total issue: 129
# https://github.com/tradytics/surpriver/issues: open issue: 9, closed issue:6, total issue: 15
# https://github.com/wemake-services/wemake-django-template/issues: open issue: 29, closed issue:487, total issue: 516
# https://github.com/al0ne/Vxscan/issues: open issue: 4, closed issue:24, total issue: 28
# https://github.com/yehengchen/Object-Detection-and-Tracking/issues: open issue: 69, closed issue:23, total issue: 92
# https://github.com/celery/django-celery/issues: open issue: 73, closed issue:334, total issue: 407
# https://github.com/VDIGPKU/M2Det/issues: open issue: 70, closed issue:45, total issue: 115
# https://github.com/berkeleydeeprlcourse/homework/issues: open issue: 4, closed issue:10, total issue: 14
# https://github.com/yanx27/Pointnet_Pointnet2_pytorch/issues: open issue: 63, closed issue:106, total issue: 169
# https://github.com/colour-science/colour/issues: open issue: 74, closed issue:467, total issue: 541
# https://github.com/m4ll0k/Infoga/issues: open issue: 25, closed issue:10, total issue: 35
# https://github.com/lepture/flask-oauthlib/issues: open issue: 11, closed issue:160, total issue: 171
# https://github.com/fundamentalvision/Deformable-DETR/issues: open issue: 86, closed issue:52, total issue: 138
# https://github.com/devnag/pytorch-generative-adversarial-networks/issues: open issue: 4, closed issue:9, total issue: 13
# https://github.com/jazzband/django-pipeline/issues: open issue: 119, closed issue:316, total issue: 435
# https://github.com/gquere/pwn_jenkins/issues: open issue: 0, closed issue:2, total issue: 2
# https://github.com/openai/generating-reviews-discovering-sentiment/issues: open issue: 22, closed issue:28, total issue: 50
# https://github.com/qinxuye/cola/issues: open issue: 13, closed issue:52, total issue: 65
# https://github.com/DenisCarriere/geocoder/issues: open issue: 73, closed issue:217, total issue: 290
# https://github.com/paulhammond/webkit2png/issues: open issue: 27, closed issue:60, total issue: 87
# https://github.com/hisxo/gitGraber/issues: open issue: 7, closed issue:13, total issue: 20
# https://github.com/jkjung-avt/tensorrt_demos/issues: open issue: 9, closed issue:496, total issue: 505
# https://github.com/rlworkgroup/garage/issues: open issue: 194, closed issue:802, total issue: 996
# https://github.com/googleprojectzero/domato/issues: open issue: 0, closed issue:4, total issue: 4
# https://github.com/thinkst/opencanary/issues: open issue: 36, closed issue:101, total issue: 137
# https://github.com/s0md3v/huepy/issues: open issue: 2, closed issue:17, total issue: 19
# https://github.com/tylerlaberge/PyPattyrn/issues: open issue: 0, closed issue:40, total issue: 40
# https://github.com/snooppr/snoop/issues: open issue: 1, closed issue:45, total issue: 46
# https://github.com/django-notifications/django-notifications/issues: open issue: 51, closed issue:136, total issue: 187
# https://github.com/garabik/grc/issues: open issue: 61, closed issue:39, total issue: 100
# https://github.com/eliemichel/MapsModelsImporter/issues: open issue: 61, closed issue:129, total issue: 190
# https://github.com/dmis-lab/biobert/issues: open issue: 43, closed issue:117, total issue: 160
# https://github.com/SCons/scons/issues: open issue: 622, closed issue:2,683, total issue: 3305
# https://github.com/watson-developer-cloud/python-sdk/issues: open issue: 2, closed issue:358, total issue: 360
# https://github.com/D4Vinci/One-Lin3r/issues: open issue: 1, closed issue:10, total issue: 11
# https://github.com/uber/petastorm/issues: open issue: 132, closed issue:139, total issue: 271
# https://github.com/vt-vl-lab/FGVC/issues: open issue: 12, closed issue:50, total issue: 62
# https://github.com/certsocietegenerale/FIR/issues: open issue: 56, closed issue:155, total issue: 211
# https://github.com/virt-manager/virt-manager/issues: open issue: 39, closed issue:222, total issue: 261
# https://github.com/reviewboard/reviewboard/issues: open issue: 1, closed issue:44, total issue: 45
# https://github.com/DerekSelander/LLDB/issues: open issue: 10, closed issue:15, total issue: 25
# https://github.com/deependersingla/deep_trader/issues: open issue: 7, closed issue:10, total issue: 17
# https://github.com/erocarrera/pefile/issues: open issue: 60, closed issue:153, total issue: 213
# https://github.com/frenck/home-assistant-config/issues: open issue: 5, closed issue:36, total issue: 41
# https://github.com/cn/GB2260/issues: open issue: 4, closed issue:19, total issue: 23
# https://github.com/littlecodersh/itchatmp/issues: open issue: 29, closed issue:20, total issue: 49
# https://github.com/taesungp/contrastive-unpaired-translation/issues: open issue: 64, closed issue:67, total issue: 131
# https://github.com/theupdateframework/python-tuf/issues: open issue: 65, closed issue:693, total issue: 758
# https://github.com/nubank/fklearn/issues: open issue: 23, closed issue:22, total issue: 45
# https://github.com/facebookresearch/votenet/issues: open issue: 73, closed issue:69, total issue: 142
# https://github.com/will8211/unimatrix/issues: open issue: 14, closed issue:6, total issue: 20
# https://github.com/nyu-mll/jiant/issues: open issue: 64, closed issue:485, total issue: 549
# https://github.com/ppwwyyxx/wechat-dump/issues: open issue: 14, closed issue:53, total issue: 67
# https://github.com/EONRaider/blackhat-python3/issues: open issue: 0, closed issue:9, total issue: 9
# https://github.com/facebookresearch/deepcluster/issues: open issue: 5, closed issue:80, total issue: 85
# https://github.com/shirosaidev/stocksight/issues: open issue: 6, closed issue:19, total issue: 25
# https://github.com/minimaxir/aitextgen/issues: open issue: 99, closed issue:65, total issue: 164
# https://github.com/x0rz/phishing_catcher/issues: open issue: 16, closed issue:7, total issue: 23
# https://github.com/ciromattia/kcc/issues: open issue: 60, closed issue:274, total issue: 334
# https://github.com/asteroid-team/asteroid/issues: open issue: 32, closed issue:147, total issue: 179
# https://github.com/rbanffy/3270font/issues: open issue: 17, closed issue:69, total issue: 86
# https://github.com/dhwajraj/deep-siamese-text-similarity/issues: open issue: 2, closed issue:7, total issue: 9
# https://github.com/githubharald/SimpleHTR/issues: open issue: 0, closed issue:121, total issue: 121
# https://github.com/tkipf/gae/issues: open issue: 45, closed issue:32, total issue: 77
# https://github.com/prompt-toolkit/pymux/issues: open issue: 35, closed issue:27, total issue: 62
# https://github.com/mshang/python-elevator-challenge/issues: open issue: 3, closed issue:1, total issue: 4
# https://github.com/ring04h/wydomain/issues: open issue: 3, closed issue:20, total issue: 23
# https://github.com/omnilib/aiomultiprocess/issues: open issue: 20, closed issue:37, total issue: 57
# https://github.com/geatpy-dev/geatpy/issues: open issue: 76, closed issue:188, total issue: 264
# https://github.com/pallets-eco/blinker/issues: open issue: 19, closed issue:16, total issue: 35
# https://github.com/s0md3v/ReconDog/issues: open issue: 7, closed issue:17, total issue: 24
# https://github.com/huggingface/pytorch-openai-transformer-lm/issues: open issue: 23, closed issue:16, total issue: 39
# https://github.com/upbit/pixivpy/issues: open issue: 10, closed issue:144, total issue: 154
# https://github.com/OpnTec/open-spectrometer-python/issues: open issue: 1, closed issue:0, total issue: 1
# https://github.com/studioimaginaire/phue/issues: open issue: 54, closed issue:68, total issue: 122
# https://github.com/facebookresearch/end-to-end-negotiator/issues: open issue: 3, closed issue:21, total issue: 24
# https://github.com/charlesq34/frustum-pointnets/issues: open issue: 80, closed issue:44, total issue: 124
# https://github.com/Hsury/BiliDrive/issues: open issue: 2, closed issue:27, total issue: 29
# https://github.com/andersbll/deeppy/issues: open issue: 20, closed issue:7, total issue: 27
# https://github.com/getpelican/pelican-plugins/issues: open issue: 77, closed issue:343, total issue: 420
# https://github.com/AmnestyTech/investigations/issues: open issue: 1, closed issue:12, total issue: 13
# https://github.com/Cloud-CV/EvalAI/issues: open issue: 128, closed issue:984, total issue: 1112
# https://github.com/trakt/Plex-Trakt-Scrobbler/issues: open issue: 178, closed issue:416, total issue: 594
# https://github.com/yinkaisheng/Python-UIAutomation-for-Windows/issues: open issue: 74, closed issue:111, total issue: 185
# https://github.com/BasioMeusPuga/Lector/issues: open issue: 39, closed issue:79, total issue: 118
# https://github.com/itcharge/LeetCode-Py/issues: open issue: 2, closed issue:0, total issue: 2
# https://github.com/terrifyzhao/bert-utils/issues: open issue: 56, closed issue:21, total issue: 77
# https://github.com/jiupinjia/stylized-neural-painting/issues: open issue: 24, closed issue:26, total issue: 50
# https://github.com/lukas-blecher/LaTeX-OCR/issues: open issue: 3, closed issue:91, total issue: 94
# https://github.com/Lucifer1993/struts-scan/issues: open issue: 1, closed issue:16, total issue: 17
# https://github.com/wuduhren/leetcode-python/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/CuriousAI/mean-teacher/issues: open issue: 36, closed issue:19, total issue: 55
# https://github.com/graykode/distribution-is-all-you-need/issues: open issue: 3, closed issue:1, total issue: 4
# https://github.com/MaartenGr/KeyBERT/issues: open issue: 14, closed issue:75, total issue: 89
# https://github.com/hyperopt/hyperopt-sklearn/issues: open issue: 69, closed issue:52, total issue: 121
# https://github.com/Lucifer1993/AngelSword/issues: open issue: 1, closed issue:8, total issue: 9
# https://github.com/bmoscon/cryptofeed/issues: open issue: 41, closed issue:361, total issue: 402
# https://github.com/pdfarranger/pdfarranger/issues: open issue: 22, closed issue:309, total issue: 331
# https://github.com/terryyin/lizard/issues: open issue: 78, closed issue:158, total issue: 236
# https://github.com/kozec/sc-controller/issues: open issue: 138, closed issue:473, total issue: 611
# https://github.com/jupyterhub/repo2docker/issues: open issue: 147, closed issue:321, total issue: 468
# https://github.com/corelan/mona/issues: open issue: 1, closed issue:34, total issue: 35
# https://github.com/mosaicml/composer/issues: open issue: 98, closed issue:270, total issue: 368
# https://github.com/leo-editor/leo-editor/issues: open issue: 128, closed issue:1,872, total issue: 2000
# https://github.com/nathanborror/django-basic-apps/issues: open issue: 12, closed issue:4, total issue: 16
# https://github.com/python-rope/rope/issues: open issue: 72, closed issue:164, total issue: 236
# https://github.com/mdipierro/nlib/issues: open issue: 7, closed issue:2, total issue: 9
# https://github.com/magicleap/SuperPointPretrainedNetwork/issues: open issue: 11, closed issue:10, total issue: 21
# https://github.com/kivy/buildozer/issues: open issue: 197, closed issue:842, total issue: 1039
# https://github.com/Sceptre/sceptre/issues: open issue: 54, closed issue:549, total issue: 603
# https://github.com/erikrose/blessings/issues: open issue: 31, closed issue:54, total issue: 85
# https://github.com/jupyter/nbconvert/issues: open issue: 401, closed issue:577, total issue: 978
# https://github.com/farcaller/DashDoc/issues: open issue: 5, closed issue:35, total issue: 40
# https://github.com/OpenNMT/OpenNMT-tf/issues: open issue: 24, closed issue:379, total issue: 403
# https://github.com/AlexiaJM/Deep-learning-with-cats/issues: open issue: 1, closed issue:14, total issue: 15
# https://github.com/google/pinject/issues: open issue: 26, closed issue:10, total issue: 36
# https://github.com/developers-against-repressions/case-212/issues: open issue: 12, closed issue:33, total issue: 45
# https://github.com/davidbombal/red-python-scripts/issues: open issue: 8, closed issue:21, total issue: 29
# https://github.com/davidaurelio/hashids-python/issues: open issue: 5, closed issue:18, total issue: 23
# https://github.com/dingdang-robot/dingdang-robot/issues: open issue: 2, closed issue:6, total issue: 8
# https://github.com/mit-han-lab/proxylessnas/issues: open issue: 0, closed issue:6, total issue: 6
# https://github.com/weiweidaolai212/BrainDamage/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/sendgrid/sendgrid-python/issues: open issue: 2, closed issue:485, total issue: 487
# https://github.com/tensorflow/recommenders/issues: open issue: 135, closed issue:121, total issue: 256
# https://github.com/SigmaQuan/Better-Python-59-Ways/issues: open issue: 8, closed issue:2, total issue: 10
# https://github.com/AxeldeRomblay/MLBox/issues: open issue: 18, closed issue:74, total issue: 92
# https://github.com/XiphosResearch/exploits/issues: open issue: 7, closed issue:6, total issue: 13
# https://github.com/openstack/openstack-ansible/issues: open issue: 0, closed issue:31, total issue: 31
# https://github.com/caogang/wgan-gp/issues: open issue: 30, closed issue:26, total issue: 56
# https://github.com/dthpham/butterflow/issues: open issue: 76, closed issue:57, total issue: 133
# https://github.com/alexa-pi/AlexaPi/issues: open issue: 129, closed issue:286, total issue: 415
# https://github.com/Kaixhin/Rainbow/issues: open issue: 8, closed issue:59, total issue: 67
# https://github.com/alanjds/drf-nested-routers/issues: open issue: 32, closed issue:62, total issue: 94
# https://github.com/holzschu/a-shell/issues: open issue: 238, closed issue:135, total issue: 373
# https://github.com/bernardopires/django-tenant-schemas/issues: open issue: 138, closed issue:327, total issue: 465
# https://github.com/res0nat0r/gitosis/issues: open issue: 3, closed issue:3, total issue: 6
# https://github.com/dropbox/pyannotate/issues: open issue: 26, closed issue:33, total issue: 59
# https://github.com/agconti/cookiecutter-django-rest/issues: open issue: 2, closed issue:232, total issue: 234
# https://github.com/jwasham/practice-python/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/deepmind/bsuite/issues: open issue: 2, closed issue:23, total issue: 25
# https://github.com/ma1co/Sony-PMCA-RE/issues: open issue: 121, closed issue:175, total issue: 296
# https://github.com/TgCatUB/catuserbot/issues: open issue: 0, closed issue:20, total issue: 20
# https://github.com/trailbehind/DeepOSM/issues: open issue: 13, closed issue:32, total issue: 45
# https://github.com/mlcommons/training/issues: open issue: 161, closed issue:81, total issue: 242
# https://github.com/nutonomy/nuscenes-devkit/issues: open issue: 0, closed issue:469, total issue: 469
# https://github.com/google-research/pegasus/issues: open issue: 80, closed issue:105, total issue: 185
# https://github.com/kozmer/log4j-shell-poc/issues: open issue: 0, closed issue:52, total issue: 52
# https://github.com/ValdikSS/blockcheck/issues: open issue: 16, closed issue:57, total issue: 73
# https://github.com/ncm2/ncm2/issues: open issue: 35, closed issue:136, total issue: 171
# https://github.com/Helpsypoo/primerpython/issues: open issue: 6, closed issue:0, total issue: 6
# https://github.com/nextstrain/ncov/issues: open issue: 50, closed issue:315, total issue: 365
# https://github.com/veekun/pokedex/issues: open issue: 120, closed issue:116, total issue: 236
# https://github.com/datastax/python-driver/issues: open issue: 11, closed issue:1,038, total issue: 1049
# https://github.com/openstack/neutron/issues: open issue: 0, closed issue:57, total issue: 57
# https://github.com/blampe/IbPy/issues: open issue: 0, closed issue:10, total issue: 10
# https://github.com/wtforms/flask-wtf/issues: open issue: 27, closed issue:274, total issue: 301
# https://github.com/fairlearn/fairlearn/issues: open issue: 138, closed issue:209, total issue: 347
# https://github.com/vim-vdebug/vdebug/issues: open issue: 44, closed issue:313, total issue: 357
# https://github.com/mdhiggins/sickbeard_mp4_automator/issues: open issue: 0, closed issue:1,416, total issue: 1416
# https://github.com/PaddlePaddle/PGL/issues: open issue: 42, closed issue:75, total issue: 117
# https://github.com/yongzhuo/Keras-TextClassification/issues: open issue: 0, closed issue:75, total issue: 75
# https://github.com/xuannianz/EfficientDet/issues: open issue: 0, closed issue:228, total issue: 228
# https://github.com/graphql-python/flask-graphql/issues: open issue: 29, closed issue:22, total issue: 51
# https://github.com/sniklaus/3d-ken-burns/issues: open issue: 6, closed issue:47, total issue: 53
# https://github.com/poodarchu/Det3D/issues: open issue: 16, closed issue:123, total issue: 139
# https://github.com/blackboxo/CleanMyWechat/issues: open issue: 8, closed issue:31, total issue: 39
# https://github.com/bread-and-pepper/django-userena/issues: open issue: 16, closed issue:221, total issue: 237
# https://github.com/H1R0GH057/Anonymous/issues: open issue: 26, closed issue:3, total issue: 29
# https://github.com/pyvista/pyvista/issues: open issue: 223, closed issue:561, total issue: 784
# https://github.com/titoBouzout/Dictionaries/issues: open issue: 1, closed issue:79, total issue: 80
# https://github.com/lonePatient/BERT-NER-Pytorch/issues: open issue: 47, closed issue:34, total issue: 81
# https://github.com/marshmallow-code/webargs/issues: open issue: 8, closed issue:270, total issue: 278
# https://github.com/ebhy/budgetml/issues: open issue: 0, closed issue:5, total issue: 5
# https://github.com/datitran/object_detector_app/issues: open issue: 16, closed issue:32, total issue: 48
# https://github.com/byt3bl33d3r/gcat/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/pyupio/safety/issues: open issue: 48, closed issue:80, total issue: 128
# https://github.com/pypa/twine/issues: open issue: 36, closed issue:370, total issue: 406
# https://github.com/realpython/flask-boilerplate/issues: open issue: 17, closed issue:7, total issue: 24
# https://github.com/Srinivas11789/PcapXray/issues: open issue: 12, closed issue:10, total issue: 22
# https://github.com/damnever/pigar/issues: open issue: 23, closed issue:41, total issue: 64
# https://github.com/django-money/django-money/issues: open issue: 50, closed issue:260, total issue: 310
# https://github.com/blackorbird/APT_REPORT/issues: open issue: 2, closed issue:0, total issue: 2
# https://github.com/dlunion/DBFace/issues: open issue: 36, closed issue:16, total issue: 52
# https://github.com/awslabs/aws-config-rules/issues: open issue: 46, closed issue:93, total issue: 139
# https://github.com/jazzband/dj-database-url/issues: open issue: 24, closed issue:49, total issue: 73
# https://github.com/raelgc/scudcloud/issues: open issue: 64, closed issue:349, total issue: 413
# https://github.com/openstack/horizon/issues: open issue: 0, closed issue:79, total issue: 79
# https://github.com/voxel51/fiftyone/issues: open issue: 221, closed issue:516, total issue: 737
# https://github.com/brandon-rhodes/fopnp/issues: open issue: 1, closed issue:30, total issue: 31
# https://github.com/marcomusy/vedo/issues: open issue: 52, closed issue:477, total issue: 529
# https://github.com/rigetti/pyquil/issues: open issue: 162, closed issue:435, total issue: 597
# https://github.com/hackappcom/ibrute/issues: open issue: 1, closed issue:0, total issue: 1
# https://github.com/ronghuaiyang/arcface-pytorch/issues: open issue: 59, closed issue:42, total issue: 101
# https://github.com/asciidisco/plugin.video.netflix/issues: open issue: 222, closed issue:362, total issue: 584
# https://github.com/syrusakbary/gdom/issues: open issue: 3, closed issue:9, total issue: 12
# https://github.com/mbi/django-simple-captcha/issues: open issue: 29, closed issue:92, total issue: 121
# https://github.com/quandl/quandl-python/issues: open issue: 3, closed issue:65, total issue: 68
# https://github.com/gabrielfalcao/lettuce/issues: open issue: 86, closed issue:218, total issue: 304
# https://github.com/KonradIT/gopro-py-api/issues: open issue: 91, closed issue:65, total issue: 156
# https://github.com/sepandhaghighi/pycm/issues: open issue: 12, closed issue:171, total issue: 183
# https://github.com/kiwiz/gkeepapi/issues: open issue: 7, closed issue:92, total issue: 99
# https://github.com/tfeldmann/organize/issues: open issue: 33, closed issue:131, total issue: 164
# https://github.com/codingforentrepreneurs/eCommerce/issues: open issue: 19, closed issue:6, total issue: 25
# https://github.com/WuJie1010/Facial-Expression-Recognition.Pytorch/issues: open issue: 28, closed issue:99, total issue: 127
# https://github.com/kfei/slack-cleaner/issues: open issue: 45, closed issue:17, total issue: 62
# https://github.com/machinalis/quepy/issues: open issue: 22, closed issue:13, total issue: 35
# https://github.com/custom-components/ble_monitor/issues: open issue: 27, closed issue:558, total issue: 585
# https://github.com/stanfordmlgroup/ngboost/issues: open issue: 24, closed issue:148, total issue: 172
# https://github.com/xyou365/AutoRclone/issues: open issue: 58, closed issue:26, total issue: 84
# https://github.com/tortilla/tortilla/issues: open issue: 5, closed issue:24, total issue: 29
# https://github.com/plctlab/v8-internals/issues: open issue: 2, closed issue:4, total issue: 6
# https://github.com/DrSleep/tensorflow-deeplab-resnet/issues: open issue: 25, closed issue:175, total issue: 200
# https://github.com/python/pythondotorg/issues: open issue: 146, closed issue:1,095, total issue: 1241
# https://github.com/djacobs/PyAPNs/issues: open issue: 35, closed issue:76, total issue: 111
# https://github.com/scikit-learn-contrib/metric-learn/issues: open issue: 45, closed issue:117, total issue: 162
# https://github.com/yhat/db.py/issues: open issue: 31, closed issue:21, total issue: 52
# https://github.com/DragonComputer/Dragonfire/issues: open issue: 39, closed issue:59, total issue: 98
# ...
# https://github.com/kivy/plyer/issues: open issue: 122, closed issue:155, total issue: 277
# https://github.com/tenable/poc/issues: open issue: 1, closed issue:7, total issue: 8
# https://github.com/google/ssl_logger/issues: open issue: 1, closed issue:2, total issue: 3
# https://github.com/python-excel/xlwt/issues: open issue: 0, closed issue:80, total issue: 80
# https://github.com/kuangliu/pytorch-retinanet/issues: open issue: 48, closed issue:25, total issue: 73
# https://github.com/araffin/rl-baselines-zoo/issues: open issue: 5, closed issue:81, total issue: 86
# https://github.com/jazzband/django-smart-selects/issues: open issue: 28, closed issue:162, total issue: 190
# https://github.com/topazproject/topaz/issues: open issue: 55, closed issue:147, total issue: 202
# https://github.com/openvinotoolkit/training_extensions/issues: open issue: 14, closed issue:245, total issue: 259
# https://github.com/facebookresearch/VMZ/issues: open issue: 27, closed issue:96, total issue: 123
# https://github.com/sleventyeleven/linuxprivchecker/issues: open issue: 1, closed issue:6, total issue: 7
# https://github.com/bookwyrm-social/bookwyrm/issues: open issue: 145, closed issue:579, total issue: 724
# https://github.com/trehn/termdown/issues: open issue: 16, closed issue:37, total issue: 53
# https://github.com/adap/flower/issues: open issue: 127, closed issue:110, total issue: 237
# https://github.com/vaastav/Fantasy-Premier-League/issues: open issue: 22, closed issue:73, total issue: 95
# https://github.com/SofianeHamlaoui/Lockdoor-Framework/issues: open issue: 1, closed issue:13, total issue: 14
# https://github.com/IronLanguages/ironpython2/issues: open issue: 197, closed issue:296, total issue: 493
# https://github.com/openai/InfoGAN/issues: open issue: 17, closed issue:4, total issue: 21
# https://github.com/vividvilla/csvtotable/issues: open issue: 11, closed issue:13, total issue: 24
# https://github.com/TylerYep/torchinfo/issues: open issue: 13, closed issue:64, total issue: 77
# https://github.com/agiliq/merchant/issues: open issue: 23, closed issue:40, total issue: 63
# https://github.com/facebook/facebook-python-business-sdk/issues: open issue: 45, closed issue:163, total issue: 208
# https://github.com/pytest-dev/pytest-bdd/issues: open issue: 105, closed issue:157, total issue: 262
# https://github.com/kartograph/kartograph.py/issues: open issue: 60, closed issue:42, total issue: 102
# https://github.com/gotgit/gotgit/issues: open issue: 15, closed issue:13, total issue: 28
# https://github.com/petl-developers/petl/issues: open issue: 73, closed issue:366, total issue: 439
# https://github.com/qwj/python-proxy/issues: open issue: 30, closed issue:99, total issue: 129
# https://github.com/Yvictor/TradingGym/issues: open issue: 4, closed issue:4, total issue: 8
# https://github.com/openseg-group/openseg.pytorch/issues: open issue: 22, closed issue:70, total issue: 92
# https://github.com/ternaus/TernausNet/issues: open issue: 8, closed issue:7, total issue: 15
# https://github.com/merantix/picasso/issues: open issue: 18, closed issue:6, total issue: 24
# https://github.com/SpiderClub/smart_login/issues: open issue: 13, closed issue:12, total issue: 25
# https://github.com/pikepdf/pikepdf/issues: open issue: 49, closed issue:219, total issue: 268
# https://github.com/wkeeling/selenium-wire/issues: open issue: 89, closed issue:367, total issue: 456
# https://github.com/TheresAFewConors/Sooty/issues: open issue: 14, closed issue:46, total issue: 60
# https://github.com/ppogg/YOLOv5-Lite/issues: open issue: 25, closed issue:105, total issue: 130
# https://github.com/tenable/poc/issues: open issue: 1, closed issue:7, total issue: 8
# https://github.com/google/ssl_logger/issues: open issue: 1, closed issue:2, total issue: 3
# https://github.com/localminimum/QANet/issues: open issue: 21, closed issue:32, total issue: 53
# https://github.com/dagrz/aws_pwn/issues: open issue: 2, closed issue:1, total issue: 3
# https://github.com/JerBouma/FundamentalAnalysis/issues: open issue: 0, closed issue:19, total issue: 19
# https://github.com/countercept/doublepulsar-detection-script/issues: open issue: 8, closed issue:12, total issue: 20
# https://github.com/timwhitez/crawlergo_x_XRAY/issues: open issue: 4, closed issue:20, total issue: 24
# https://github.com/OTRF/OSSEM/issues: open issue: 13, closed issue:26, total issue: 39
# https://github.com/HaddyYang/django2.0-course/issues: open issue: 0, closed issue:12, total issue: 12
# https://github.com/python-excel/xlwt/issues: open issue: 0, closed issue:80, total issue: 80
# https://github.com/rhiever/datacleaner/issues: open issue: 9, closed issue:4, total issue: 13
# https://github.com/yihong0618/GitHubPoster/issues: open issue: 3, closed issue:25, total issue: 28
# https://github.com/kuangliu/pytorch-retinanet/issues: open issue: 48, closed issue:25, total issue: 73
# https://github.com/araffin/rl-baselines-zoo/issues: open issue: 5, closed issue:81, total issue: 86
# https://github.com/jazzband/django-smart-selects/issues: open issue: 28, closed issue:162, total issue: 190
# https://github.com/topazproject/topaz/issues: open issue: 55, closed issue:147, total issue: 202
# https://github.com/openvinotoolkit/training_extensions/issues: open issue: 14, closed issue:245, total issue: 259
# https://github.com/facebookresearch/VMZ/issues: open issue: 27, closed issue:96, total issue: 123
# https://github.com/sleventyeleven/linuxprivchecker/issues: open issue: 1, closed issue:6, total issue: 7
# https://github.com/facebook/facebook-python-business-sdk/issues: open issue: 45, closed issue:163, total issue: 208
# https://github.com/hustvl/YOLOP/issues: open issue: 64, closed issue:44, total issue: 108
# https://github.com/dmontagu/fastapi-utils/issues: open issue: 28, closed issue:12, total issue: 40
# https://github.com/dstmath/frida-unpack/issues: open issue: 9, closed issue:6, total issue: 15
# https://github.com/jaraco/path/issues: open issue: 1, closed issue:127, total issue: 128
# https://github.com/google-research/morph-net/issues: open issue: 11, closed issue:45, total issue: 56
# https://github.com/Ice-Cirno/HoshinoBot/issues: open issue: 10, closed issue:118, total issue: 128
# https://github.com/FeeiCN/ESD/issues: open issue: 7, closed issue:49, total issue: 56
# https://github.com/kmike/pymorphy2/issues: open issue: 69, closed issue:64, total issue: 133
# https://github.com/softScheck/tplink-smartplug/issues: open issue: 42, closed issue:24, total issue: 66
# https://github.com/alex04072000/ObstructionRemoval/issues: open issue: 14, closed issue:7, total issue: 21
# https://github.com/blaze/odo/issues: open issue: 191, closed issue:106, total issue: 297
# https://github.com/PolyAI-LDN/conversational-datasets/issues: open issue: 14, closed issue:10, total issue: 24
# https://github.com/ibayer/fastFM/issues: open issue: 46, closed issue:60, total issue: 106
# https://github.com/jealous/stockstats/issues: open issue: 8, closed issue:77, total issue: 85
# https://github.com/tasmota/tasmotizer/issues: open issue: 27, closed issue:67, total issue: 94
# https://github.com/shiyybua/NER/issues: open issue: 69, closed issue:10, total issue: 79
# https://github.com/autonomousvision/giraffe/issues: open issue: 1, closed issue:48, total issue: 49
# https://github.com/enthought/mayavi/issues: open issue: 367, closed issue:389, total issue: 756
# https://github.com/igraph/python-igraph/issues: open issue: 36, closed issue:357, total issue: 393
# https://github.com/jseidl/GoldenEye/issues: open issue: 0, closed issue:6, total issue: 6
# https://github.com/rachpt/lanzou-gui/issues: open issue: 0, closed issue:2, total issue: 2
# https://github.com/YoYo000/MVSNet/issues: open issue: 64, closed issue:75, total issue: 139
# https://github.com/uber/fiber/issues: open issue: 16, closed issue:8, total issue: 24
# https://github.com/jacobgil/keras-dcgan/issues: open issue: 24, closed issue:5, total issue: 29
# https://github.com/makcedward/nlp/issues: open issue: 8, closed issue:3, total issue: 11
# https://github.com/kingyiusuen/image-to-latex/issues: open issue: 10, closed issue:7, total issue: 17
# https://github.com/GoSecure/malboxes/issues: open issue: 24, closed issue:56, total issue: 80
# https://github.com/8080labs/pyforest/issues: open issue: 8, closed issue:14, total issue: 22
# https://github.com/rpm-software-management/dnf/issues: open issue: 18, closed issue:1,804, total issue: 1822
# https://github.com/binarymatt/pyres/issues: open issue: 17, closed issue:79, total issue: 96
# https://github.com/wannabeOG/Mask-RCNN/issues: open issue: 16, closed issue:5, total issue: 21
# https://github.com/altosaar/variational-autoencoder/issues: open issue: 1, closed issue:24, total issue: 25
# https://github.com/fogleman/sdf/issues: open issue: 12, closed issue:13, total issue: 25
# https://github.com/lepture/python-livereload/issues: open issue: 41, closed issue:99, total issue: 140
# https://github.com/zostera/django-bootstrap4/issues: open issue: 21, closed issue:136, total issue: 157
# https://github.com/hubert3/iSniff-GPS/issues: open issue: 10, closed issue:18, total issue: 28
# https://github.com/neuroradiology/InsideReCaptcha/issues: open issue: 0, closed issue:2, total issue: 2
# https://github.com/rosinality/vq-vae-2-pytorch/issues: open issue: 39, closed issue:29, total issue: 68
# https://github.com/jimmyxu/chnroutes/issues: open issue: 16, closed issue:2, total issue: 18
# https://github.com/bczsalba/pytermgui/issues: open issue: 6, closed issue:27, total issue: 33
# https://github.com/webrecorder/pywb/issues: open issue: 90, closed issue:283, total issue: 373
# https://github.com/google-research/batch-ppo/issues: open issue: 4, closed issue:19, total issue: 23
# https://github.com/mobier/shadowsocksr-speed/issues: open issue: 20, closed issue:73, total issue: 93
# https://github.com/xHak9x/fbi/issues: open issue: 7, closed issue:1, total issue: 8
# https://github.com/eliasgranderubio/dagda/issues: open issue: 12, closed issue:64, total issue: 76
# https://github.com/mido/mido/issues: open issue: 118, closed issue:113, total issue: 231
# https://github.com/facebookresearch/FixRes/issues: open issue: 4, closed issue:30, total issue: 34
# https://github.com/brightmart/bert_language_understanding/issues: open issue: 7, closed issue:14, total issue: 21
# https://github.com/rusty1s/pytorch_scatter/issues: open issue: 21, closed issue:235, total issue: 256
# https://github.com/YoSmudge/dnsyo/issues: open issue: 2, closed issue:15, total issue: 17
# https://github.com/Al-Azif/ps4-exploit-host/issues: open issue: 7, closed issue:188, total issue: 195
# https://github.com/jmathai/elodie/issues: open issue: 71, closed issue:163, total issue: 234
# https://github.com/nateshmbhat/pyttsx3/issues: open issue: 102, closed issue:96, total issue: 198
# https://github.com/minitorch/minitorch/issues: open issue: 1, closed issue:0, total issue: 1
# https://github.com/mlouielu/twstock/issues: open issue: 28, closed issue:29, total issue: 57
# https://github.com/xinxin8816/gfriends/issues: open issue: 9, closed issue:48, total issue: 57
# https://github.com/SleepyBag/Statistical-Learning-Methods/issues: open issue: 0, closed issue:1, total issue: 1
# https://github.com/reclosedev/requests-cache/issues: open issue: 19, closed issue:289, total issue: 308
# https://github.com/roxma/nvim-completion-manager/issues: open issue: 28, closed issue:159, total issue: 187
# https://github.com/TingFree/NLPer-Arsenal/issues: open issue: 1, closed issue:6, total issue: 7
# https://github.com/whyliam/whyliam.workflows.youdao/issues: open issue: 4, closed issue:78, total issue: 82
# https://github.com/bitcoin-abe/bitcoin-abe/issues: open issue: 138, closed issue:77, total issue: 215
# https://github.com/davda54/sam/issues: open issue: 4, closed issue:53, total issue: 57
# https://github.com/joeddav/devol/issues: open issue: 7, closed issue:20, total issue: 27
# https://github.com/san089/goodreads_etl_pipeline/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/bytefish/facerec/issues: open issue: 1, closed issue:9, total issue: 10
# https://github.com/pygments/pygments/issues: open issue: 336, closed issue:1,246, total issue: 1582
# https://github.com/RaRe-Technologies/bounter/issues: open issue: 16, closed issue:9, total issue: 25
# https://github.com/standardebooks/tools/issues: open issue: 5, closed issue:164, total issue: 169
# https://github.com/ZeroQI/Hama.bundle/issues: open issue: 9, closed issue:408, total issue: 417
# https://github.com/GeospatialPython/pyshp/issues: open issue: 16, closed issue:133, total issue: 149
# https://github.com/Netflix/aminator/issues: open issue: 22, closed issue:58, total issue: 80
# https://github.com/sngyai/Sequoia/issues: open issue: 13, closed issue:14, total issue: 27
# https://github.com/streamlit/demo-self-driving/issues: open issue: 1, closed issue:8, total issue: 9
# https://github.com/pytest-dev/pytest-asyncio/issues: open issue: 24, closed issue:175, total issue: 199
# https://github.com/m-labs/migen/issues: open issue: 44, closed issue:78, total issue: 122
# https://github.com/vesche/scanless/issues: open issue: 2, closed issue:12, total issue: 14
# https://github.com/EvgenyKashin/stylegan2-distillation/issues: open issue: 1, closed issue:34, total issue: 35
# https://github.com/flyyufelix/cnn_finetune/issues: open issue: 31, closed issue:27, total issue: 58
# https://github.com/secretsquirrel/BDFProxy/issues: open issue: 2, closed issue:7, total issue: 9
# https://github.com/collerek/ormar/issues: open issue: 22, closed issue:146, total issue: 168
# https://github.com/berinhard/model_mommy/issues: open issue: 0, closed issue:185, total issue: 185
# https://github.com/codingo/VHostScan/issues: open issue: 7, closed issue:43, total issue: 50
# https://github.com/rdnetto/YCM-Generator/issues: open issue: 36, closed issue:58, total issue: 94
# https://github.com/Matoking/protontricks/issues: open issue: 7, closed issue:123, total issue: 130
# https://github.com/marin-m/pbtk/issues: open issue: 13, closed issue:8, total issue: 21
# https://github.com/AimeeLee77/keyword_extraction/issues: open issue: 9, closed issue:3, total issue: 12
# https://github.com/RhinoSecurityLabs/Security-Research/issues: open issue: 8, closed issue:6, total issue: 14
# https://github.com/cburmeister/flask-bones/issues: open issue: 0, closed issue:18, total issue: 18
# https://github.com/srusskih/SublimeJEDI/issues: open issue: 33, closed issue:185, total issue: 218
# https://github.com/python-versioneer/python-versioneer/issues: open issue: 51, closed issue:123, total issue: 174
# https://github.com/aliyun/aliyun-openapi-python-sdk/issues: open issue: 13, closed issue:162, total issue: 175
# https://github.com/sourcerer-io/hall-of-fame/issues: open issue: 15, closed issue:9, total issue: 24
# https://github.com/tensorflow/neural-structured-learning/issues: open issue: 1, closed issue:59, total issue: 60
# https://github.com/Garvit244/Leetcode/issues: open issue: 0, closed issue:0, total issue: 0
# https://github.com/aneesha/RAKE/issues: open issue: 8, closed issue:1, total issue: 9
# https://github.com/pollen-robotics/dtw/issues: open issue: 7, closed issue:26, total issue: 33
# https://github.com/noripyt/django-cachalot/issues: open issue: 16, closed issue:124, total issue: 140
# https://github.com/barronwaffles/dwc_network_server_emulator/issues: open issue: 11, closed issue:465, total issue: 476
# https://github.com/farzaa/DeepLeague/issues: open issue: 2, closed issue:18, total issue: 20
# https://github.com/wubinzzu/NeuRec/issues: open issue: 13, closed issue:16, total issue: 29
# https://github.com/simpleai-team/simpleai/issues: open issue: 12, closed issue:13, total issue: 25
# https://github.com/chaoming0625/SentimentPolarityAnalysis/issues: open issue: 7, closed issue:11, total issue: 18
# https://github.com/DeepGraphLearning/RecommenderSystems/issues: open issue: 6, closed issue:14, total issue: 20
# https://github.com/gurnec/btcrecover/issues: open issue: 318, closed issue:132, total issue: 450
# https://github.com/netbox-community/netbox-docker/issues: open issue: 7, closed issue:222, total issue: 229

# %%
for i in range(df.shape[0]):
    if df.loc[i, "total_issue_count"] == 0:
        df.loc[i, "total_issue_count"] = df.loc[i, "open_issues"]
    elif df.loc[i, "total_issue_count"] < df.loc[i, "open_issues"]:
        df.loc[i, "total_issue_count"] = df.loc[i, "open_issues"]

# %%
df["commit_count"] = df["commit_count"].replace(0, df["commit_count"].mean())

# %%
df.isnull().sum()
# Out:
# allow_forking        0
# commit_count         0
# contributor_count    0
# created_at           0
# forks                0
# github_pages         0
# license              0
# name                 0
# open_issues          0
# size                 0
# star_count           0
# topics_count         0
# total_issue_count    0
# updated_at           0
# url                  0
# watchers_count       0
# dtype: int64

# %%
df.describe()
# Out:
#        allow_forking   commit_count  contributor_count        forks  \
# count         4100.0    4100.000000        4100.000000  4100.000000
# mean             1.0    1584.557561          60.614956   566.492683
# std              0.0    6634.910726         171.497638   612.552046
# min              1.0       1.000000           2.000000     3.000000
# 25%              1.0      92.000000           7.000000   215.750000
# 50%              1.0     328.500000          22.000000   381.000000
# 75%              1.0    1086.000000          60.614956   667.000000
# max              1.0  232549.000000        5602.000000  6268.000000
#
#        github_pages  open_issues          size   star_count  topics_count  \
# count   4100.000000  4100.000000  4.100000e+03  4100.000000   4100.000000
# mean       0.161463    90.137805  6.746921e+04  2733.256829      5.118780
# std        0.368003   200.877626  1.046066e+06  2078.212911      5.462667
# min        0.000000     0.000000  0.000000e+00   914.000000      0.000000
# 25%        0.000000    12.000000  8.200000e+02  1325.000000      0.000000
# 50%        0.000000    36.000000  4.793000e+03  1946.500000      4.000000
# 75%        0.000000    93.000000  2.784425e+04  2994.000000      8.000000
# max        1.000000  4427.000000  5.701610e+07  9998.000000     20.000000
#
#        total_issue_count  watchers_count
# count        4100.000000     4100.000000
# mean          392.680732     2733.256829
# std           974.554700     2078.212911
# min             0.000000      914.000000
# 25%            48.000000     1325.000000
# 50%           136.000000     1946.500000
# 75%           368.000000     2994.000000
# max         30188.000000     9998.000000

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Add how many years the project has been developed

# %%
df["created_at"] = pd.to_datetime(df["created_at"])
df["updated_at"] = pd.to_datetime(df["updated_at"])
df["years"] = (df["updated_at"] - df["created_at"]) / np.timedelta64(1, 'Y')
df["years"] = df["years"].astype(np.int32)

# %% [markdown]
# ### Find the closed issue count, add closed issue rate (closed / all)

# %%
df["closed_issue"] = df["total_issue_count"] - df["open_issues"]
df["issue_close_rate"] = df["closed_issue"] / df["total_issue_count"]
df["issue_close_rate"] = df["issue_close_rate"].fillna(0)
df[["closed_issue", "issue_close_rate", "total_issue_count"]]
# Out:
#       closed_issue  issue_close_rate  total_issue_count
# 0            679.0          0.659223             1030.0
# 1             74.0          0.755102               98.0
# 2            105.0          0.714286              147.0
# 3           2091.0          0.760364             2750.0
# 4             53.0          0.803030               66.0
# ...            ...               ...                ...
# 4095          12.0          0.480000               25.0
# 4096          11.0          0.611111               18.0
# 4097          14.0          0.700000               20.0
# 4098         123.0          0.273333              450.0
# 4099         215.0          0.938865              229.0
#
# [4100 rows x 3 columns]

# %%
df.describe()
# Out:
#        allow_forking   commit_count  contributor_count        forks  \
# count         4100.0    4100.000000        4100.000000  4100.000000
# mean             1.0    1584.557561          60.614956   566.492683
# std              0.0    6634.910726         171.497638   612.552046
# min              1.0       1.000000           2.000000     3.000000
# 25%              1.0      92.000000           7.000000   215.750000
# 50%              1.0     328.500000          22.000000   381.000000
# 75%              1.0    1086.000000          60.614956   667.000000
# max              1.0  232549.000000        5602.000000  6268.000000
#
#        github_pages  open_issues          size   star_count  topics_count  \
# count   4100.000000  4100.000000  4.100000e+03  4100.000000   4100.000000
# mean       0.161463    90.137805  6.746921e+04  2733.256829      5.118780
# std        0.368003   200.877626  1.046066e+06  2078.212911      5.462667
# min        0.000000     0.000000  0.000000e+00   914.000000      0.000000
# 25%        0.000000    12.000000  8.200000e+02  1325.000000      0.000000
# 50%        0.000000    36.000000  4.793000e+03  1946.500000      4.000000
# 75%        0.000000    93.000000  2.784425e+04  2994.000000      8.000000
# max        1.000000  4427.000000  5.701610e+07  9998.000000     20.000000
#
#        total_issue_count  watchers_count        years  closed_issue  \
# count        4100.000000     4100.000000  4100.000000   4100.000000
# mean          392.680732     2733.256829     5.215610    302.542927
# std           974.554700     2078.212911     2.954043    849.421880
# min             0.000000      914.000000     0.000000      0.000000
# 25%            48.000000     1325.000000     3.000000     22.750000
# 50%           136.000000     1946.500000     5.000000     85.000000
# 75%           368.000000     2994.000000     7.000000    262.250000
# max         30188.000000     9998.000000    13.000000  29904.000000
#
#        issue_close_rate
# count       4100.000000
# mean           0.634587
# std            0.274394
# min            0.000000
# 25%            0.450000
# 50%            0.691685
# 75%            0.857143
# max            1.000000

# %% [markdown]
# ### Mapping Licence to Commercial Use

# %%
df["license"].value_counts()
# Out:
# MIT License                                                   1403
# Apache License 2.0                                             666
# Other                                                          637
# Not Found                                                      472
# GNU General Public License v3.0                                335
# BSD 3-Clause "New" or "Revised" License                        229
# GNU General Public License v2.0                                 82
# BSD 2-Clause "Simplified" License                               80
# GNU Affero General Public License v3.0                          69
# GNU Lesser General Public License v3.0                          34
# Mozilla Public License 2.0                                      20
# Creative Commons Zero v1.0 Universal                            19
# The Unlicense                                                   15
# Creative Commons Attribution Share Alike 4.0 International       8
# GNU Lesser General Public License v2.1                           8
# ISC License                                                      6
# SIL Open Font License 1.1                                        4
# MIT No Attribution                                               4
# Creative Commons Attribution 4.0 International                   3
# Eclipse Public License 1.0                                       2
# Do What The F*ck You Want To Public License                      1
# zlib License                                                     1
# Artistic License 2.0                                             1
# PostgreSQL License                                               1
# Name: license, dtype: int64

# %% [markdown]
# All of the licences are free for commercial usage, therefore this is not useful. Will drop `license` column

# %%
df.head()
# Out:
#    allow_forking  commit_count  contributor_count                created_at  \
# 0            1.0          5524              312.0 2020-05-19 02:37:13+00:00
# 1            1.0           224               16.0 2017-08-25 12:05:15+00:00
# 2            1.0           133                3.0 2018-01-09 09:48:49+00:00
# 3            1.0          6023               18.0 2018-07-11 18:28:58+00:00
# 4            1.0           541                9.0 2016-05-29 13:29:44+00:00
#
#     forks  github_pages                                 license  \
# 0   882.0           0.0                             MIT License
# 1  2590.0           0.0                             MIT License
# 2  2181.0           0.0                      Apache License 2.0
# 3  1494.0           1.0  GNU Lesser General Public License v3.0
# 4  5612.0           0.0                             MIT License
#
#                              name  open_issues      size  star_count  \
# 0            ManimCommunity/manim        351.0   33506.0      9951.0
# 1   zalandoresearch/fashion-mnist         24.0  108395.0      9998.0
# 2  Embedding/Chinese-Word-Vectors         42.0    1477.0      9976.0
# 3         PySimpleGUI/PySimpleGUI        659.0  261676.0      9924.0
# 4            MorvanZhou/tutorials         13.0   62652.0      9944.0
#
#    topics_count  total_issue_count                updated_at  \
# 0           4.0             1030.0 2022-05-09 17:53:54+00:00
# 1          11.0               98.0 2022-05-09 09:30:18+00:00
# 2           6.0              147.0 2022-05-09 14:13:08+00:00
# 3          20.0             2750.0 2022-05-09 15:50:27+00:00
# 4           9.0               66.0 2022-05-09 11:56:21+00:00
#
#                                                  url  watchers_count  years  \
# 0            https://github.com/ManimCommunity/manim          9951.0      1
# 1   https://github.com/zalandoresearch/fashion-mnist          9998.0      4
# 2  https://github.com/Embedding/Chinese-Word-Vectors          9976.0      4
# 3         https://github.com/PySimpleGUI/PySimpleGUI          9924.0      3
# 4            https://github.com/MorvanZhou/tutorials          9944.0      5
#
#    closed_issue  issue_close_rate
# 0         679.0          0.659223
# 1          74.0          0.755102
# 2         105.0          0.714286
# 3        2091.0          0.760364
# 4          53.0          0.803030

# %% [markdown]
# `Watcher Count` is directly related with the star count, therefore we drop that column

# %% [markdown]
# ## Categorize the star counts

# %%
df["star_category"] = df["star_count"].map(lambda x: (x // 1000) + 1)

# %%
df["star_category"].value_counts()
# Out:
# 2.0     1765
# 3.0      909
# 1.0      408
# 4.0      241
# 5.0      224
# 6.0      159
# 9.0      127
# 7.0      111
# 10.0      82
# 8.0       74
# Name: star_category, dtype: int64

# %%
X = df.drop(columns=["created_at", "license", "name", "updated_at", "url", "watchers_count", "star_count", "star_category"])
Y = df["star_category"].values

# %%
X.shape, Y.shape
# Out:
# ((4100, 12), (4100,))

# %% [markdown]
# ## Preparing Train and Test Data
# We will split train to test as 80%, 20&

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=50, test_size=0.2)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3280, 12), (3280,), (820, 12), (820,))

# %% [markdown]
# ## Apply Baseline Machine Learning Model

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
for i in range(1, 21):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train, y_train)
    preds = neigh.predict(X_test)
    print(f"for neighbour: {i} : accuracy: {accuracy_score(y_test, preds)}")
# Out:
# for neighbour: 1 : accuracy: 0.49390243902439024
# for neighbour: 2 : accuracy: 0.4560975609756098
# for neighbour: 3 : accuracy: 0.45121951219512196
# for neighbour: 4 : accuracy: 0.4317073170731707
# for neighbour: 5 : accuracy: 0.43414634146341463
# for neighbour: 6 : accuracy: 0.4451219512195122
# for neighbour: 7 : accuracy: 0.44146341463414634
# for neighbour: 8 : accuracy: 0.4475609756097561
# for neighbour: 9 : accuracy: 0.4451219512195122
# for neighbour: 10 : accuracy: 0.44146341463414634
# for neighbour: 11 : accuracy: 0.44146341463414634
# for neighbour: 12 : accuracy: 0.4378048780487805
# for neighbour: 13 : accuracy: 0.4475609756097561
# for neighbour: 14 : accuracy: 0.44634146341463415
# for neighbour: 15 : accuracy: 0.4475609756097561
# for neighbour: 16 : accuracy: 0.4402439024390244
# for neighbour: 17 : accuracy: 0.43414634146341463
# for neighbour: 18 : accuracy: 0.43414634146341463
# for neighbour: 19 : accuracy: 0.4317073170731707
# for neighbour: 20 : accuracy: 0.4195121951219512

# %% [markdown]
# # Different Machine Learning Models
#
# - support vector machine
# - gaussian naive bayes

# %%
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn import tree

models = {
    "SVC": svm.SVC(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": tree.DecisionTreeClassifier(),
}

for name, model in models.items():

    model.fit(X_train, y_train)

    preds = model.predict(X_test)

    print(f"Accuracy score for {name} : {accuracy_score(y_test, preds)}")
# Out:
# Accuracy score for SVC : 0.4121951219512195
# Accuracy score for Naive Bayes : 0.4195121951219512
# Accuracy score for Decision Tree : 0.5

# %%
model = svm.SVC()

model.fit(X_train, y_train)

preds = model.predict(X_test)

print(f"Accuracy score for SVC: {accuracy_score(y_test, preds)}")
# Out:
# Accuracy score for SVC: 0.4121951219512195

# %%
model = GaussianNB()

model.fit(X_train, y_train)

preds = model.predict(X_test)

print(f"Accuracy score for Naive Bayes: {accuracy_score(y_test, preds)}")
# Out:
# Accuracy score for Naive Bayes: 0.4195121951219512

# %%
model = tree.DecisionTreeClassifier()

model.fit(X_train, y_train)

preds = model.predict(X_test)

print(f"Accuracy score for Decision Tree: {accuracy_score(y_test, preds)}")
# Out:
# Accuracy score for Decision Tree: 0.49390243902439024
